# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
columns = ['d_loss']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['g_loss']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['s_loss']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['d_loss_real','d_loss_fake','g_loss_fake']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['g_loss_seg_','g_loss_cls','g_loss_fake','g_loss_rec','g_loss']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['g_loss_seg_','g_loss_cls','g_loss_fake']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['g_loss_rec','g_loss']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['d_loss','d_loss_real','d_loss_fake','d_loss_cls','d_loss_gp']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['d_loss_real','d_loss_fake']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['d_loss_cls','d_loss_gp','g_loss_cls','g_loss_seg_','d_loss_real','d_loss_fake','g_loss_fake']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['d_loss_cls','d_loss_gp','g_loss_cls','g_loss_seg_']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()

# %%
columns = ['g_loss_rec']
df = pd.read_csv("./SIMO/loggan_simo_cls.csv",usecols=columns)
df.plot()
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.show()
